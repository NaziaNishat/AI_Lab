# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-81d104b7-77e9-4213-97cd-48d9490c68cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81d104b7-77e9-4213-97cd-48d9490c68cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving KaggleHousePrices.csv to KaggleHousePrices.csv

# %%
df = pd.read_csv('KaggleHousePrices.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
# Find columns with missing values and their percent missing
df.isnull().sum()                                                     
miss_val = df.isnull().sum().sort_values(ascending=False)
miss_val = pd.DataFrame(data=df.isnull().sum().sort_values(ascending=False), columns=['MissvalCount'])

# Add a new column to the dataframe and fill it with the percentage of missing values
miss_val['Percent'] = miss_val.MissvalCount.apply(lambda x : '{:.2f}'.format(float(x)/df.shape[0] * 100)) 
miss_val = miss_val[miss_val.MissvalCount > 0]
miss_val
# Out:
#               MissvalCount Percent
# PoolQC                1453   99.52
# MiscFeature           1406   96.30
# Alley                 1369   93.77
# Fence                 1179   80.75
# FireplaceQu            690   47.26
# LotFrontage            259   17.74
# GarageCond              81    5.55
# GarageType              81    5.55
# GarageYrBlt             81    5.55
# GarageFinish            81    5.55
# GarageQual              81    5.55
# BsmtExposure            38    2.60
# BsmtFinType2            38    2.60
# BsmtFinType1            37    2.53
# BsmtCond                37    2.53
# BsmtQual                37    2.53
# MasVnrArea               8    0.55
# MasVnrType               8    0.55
# Electrical               1    0.07

# %%
# drop columns with high missing values
df = df.drop(['Fence', 'MiscFeature', 'PoolQC','FireplaceQu','Alley'], axis=1)

# drop rows with any missing values
df.dropna(inplace=True)

# %% [markdown]
# **Explore data**

# %%
# Check distribution of target variable
sns.distplot(df.SalePrice)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Transform the target variable 
sns.distplot(np.log(df.SalePrice))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['LogOfPrice'] = np.log(df.SalePrice)
df.drop(["SalePrice"], axis=1, inplace=True)

# %%
# Review the skewness of each feature
df.skew().sort_values(ascending=False)
# Out:
# LotArea          15.508309
# PoolArea         13.614615
# 3SsnPorch        11.069793
# LowQualFinSF      9.896145
# MiscVal           9.673292
# KitchenAbvGr      5.587741
# BsmtFinSF2        4.372440
# BsmtHalfBath      4.049639
# ScreenPorch       3.962075
# EnclosedPorch     3.165433
# MasVnrArea        2.695262
# OpenPorchSF       2.382985
# TotalBsmtSF       2.314581
# LotFrontage       2.227272
# BsmtFinSF1        1.931425
# GrLivArea         1.553875
# WoodDeckSF        1.525006
# MSSubClass        1.428836
# 1stFlrSF          1.371529
# BsmtUnfSF         0.884701
# OverallCond       0.862376
# 2ndFlrSF          0.790156
# GarageArea        0.726787
# TotRmsAbvGrd      0.721070
# Fireplaces        0.629886
# HalfBath          0.607079
# BsmtFullBath      0.532962
# LogOfPrice        0.304486
# OverallQual       0.298295
# GarageCars        0.210251
# MoSold            0.168709
# YrSold            0.122460
# Id                0.020785
# FullBath          0.019856
# BedroomAbvGr      0.016689
# YearRemodAdd     -0.585271
# YearBuilt        -0.633765
# GarageYrBlt      -0.661044
# dtype: float64

# %% [markdown]
# **Train-Test Split dataset**

# %%
from sklearn.model_selection import train_test_split

# %%
# set the target and predictors
y = df.LogOfPrice  # target

# use only those input features with numeric data type 
df_temp = df.select_dtypes(include=["int64","float64"]) 
X = df_temp.drop(["LogOfPrice"],axis=1)  # predictors

# %%
# split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# **Modeling**

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()

# Fitting the ANN to the Training set
hist=NN_model.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_50 (Dense)             (None, 128)               4864
# _________________________________________________________________
# dense_51 (Dense)             (None, 256)               33024
# _________________________________________________________________
# dense_52 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_53 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_54 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 169,729
# Trainable params: 169,729
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 52/52 [==============================] - 1s 8ms/step - loss: 27.1982 - mean_absolute_error: 27.1982 - val_loss: 2.2717 - val_mean_absolute_error: 2.2717
# Epoch 2/100
# 52/52 [==============================] - 0s 4ms/step - loss: 1.5896 - mean_absolute_error: 1.5896 - val_loss: 0.7131 - val_mean_absolute_error: 0.7131
# Epoch 3/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.7979 - mean_absolute_error: 0.7979 - val_loss: 1.1352 - val_mean_absolute_error: 1.1352
# Epoch 4/100
# 52/52 [==============================] - 0s 4ms/step - loss: 1.1239 - mean_absolute_error: 1.1239 - val_loss: 2.4430 - val_mean_absolute_error: 2.4430
# Epoch 5/100
# 52/52 [==============================] - 0s 4ms/step - loss: 1.6378 - mean_absolute_error: 1.6378 - val_loss: 1.4188 - val_mean_absolute_error: 1.4188
# Epoch 6/100
# 52/52 [==============================] - 0s 4ms/step - loss: 1.0312 - mean_absolute_error: 1.0312 - val_loss: 0.6713 - val_mean_absolute_error: 0.6713
# Epoch 7/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.7961 - mean_absolute_error: 0.7961 - val_loss: 0.5328 - val_mean_absolute_error: 0.5328
# Epoch 8/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5818 - mean_absolute_error: 0.5818 - val_loss: 0.3537 - val_mean_absolute_error: 0.3537
# Epoch 9/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.6578 - mean_absolute_error: 0.6578 - val_loss: 0.6491 - val_mean_absolute_error: 0.6491
# Epoch 10/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.9133 - mean_absolute_error: 0.9133 - val_loss: 0.4498 - val_mean_absolute_error: 0.4498
# Epoch 11/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5259 - mean_absolute_error: 0.5259 - val_loss: 1.8046 - val_mean_absolute_error: 1.8046
# Epoch 12/100
# 52/52 [==============================] - 0s 5ms/step - loss: 1.1668 - mean_absolute_error: 1.1668 - val_loss: 0.6021 - val_mean_absolute_error: 0.6021
# Epoch 13/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.7058 - mean_absolute_error: 0.7058 - val_loss: 0.4869 - val_mean_absolute_error: 0.4869
# Epoch 14/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.8835 - mean_absolute_error: 0.8835 - val_loss: 0.9431 - val_mean_absolute_error: 0.9431
# Epoch 15/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.9132 - mean_absolute_error: 0.9132 - val_loss: 1.4570 - val_mean_absolute_error: 1.4570
# Epoch 16/100
# 52/52 [==============================] - 0s 5ms/step - loss: 1.5398 - mean_absolute_error: 1.5398 - val_loss: 0.5476 - val_mean_absolute_error: 0.5476
# Epoch 17/100
# 52/52 [==============================] - 0s 5ms/step - loss: 1.3602 - mean_absolute_error: 1.3602 - val_loss: 0.4176 - val_mean_absolute_error: 0.4176
# Epoch 18/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4981 - mean_absolute_error: 0.4981 - val_loss: 0.2682 - val_mean_absolute_error: 0.2682
# Epoch 19/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.5415 - mean_absolute_error: 0.5415 - val_loss: 0.5290 - val_mean_absolute_error: 0.5290
# Epoch 20/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4202 - mean_absolute_error: 0.4202 - val_loss: 0.4820 - val_mean_absolute_error: 0.4820
# Epoch 21/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4593 - mean_absolute_error: 0.4593 - val_loss: 0.4333 - val_mean_absolute_error: 0.4333
# Epoch 22/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3895 - mean_absolute_error: 0.3895 - val_loss: 0.5679 - val_mean_absolute_error: 0.5679
# Epoch 23/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4832 - mean_absolute_error: 0.4832 - val_loss: 0.1776 - val_mean_absolute_error: 0.1776
# Epoch 24/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2136 - mean_absolute_error: 0.2136 - val_loss: 0.4955 - val_mean_absolute_error: 0.4955
# Epoch 25/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.5166 - mean_absolute_error: 0.5166 - val_loss: 0.2490 - val_mean_absolute_error: 0.2490
# Epoch 26/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2388 - mean_absolute_error: 0.2388 - val_loss: 0.4244 - val_mean_absolute_error: 0.4244
# Epoch 27/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4994 - mean_absolute_error: 0.4994 - val_loss: 0.2762 - val_mean_absolute_error: 0.2762
# Epoch 28/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4049 - mean_absolute_error: 0.4049 - val_loss: 0.3025 - val_mean_absolute_error: 0.3025
# Epoch 29/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3127 - mean_absolute_error: 0.3127 - val_loss: 0.2087 - val_mean_absolute_error: 0.2087
# Epoch 30/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2736 - mean_absolute_error: 0.2736 - val_loss: 0.1913 - val_mean_absolute_error: 0.1913
# Epoch 31/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2724 - mean_absolute_error: 0.2724 - val_loss: 0.6355 - val_mean_absolute_error: 0.6355
# Epoch 32/100
# 52/52 [==============================] - 0s 9ms/step - loss: 0.4881 - mean_absolute_error: 0.4881 - val_loss: 0.2267 - val_mean_absolute_error: 0.2267
# Epoch 33/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3929 - mean_absolute_error: 0.3929 - val_loss: 0.2243 - val_mean_absolute_error: 0.2243
# Epoch 34/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3511 - mean_absolute_error: 0.3511 - val_loss: 0.3619 - val_mean_absolute_error: 0.3619
# Epoch 35/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3746 - mean_absolute_error: 0.3746 - val_loss: 0.2445 - val_mean_absolute_error: 0.2445
# Epoch 36/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2198 - mean_absolute_error: 0.2198 - val_loss: 0.3651 - val_mean_absolute_error: 0.3651
# Epoch 37/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3196 - mean_absolute_error: 0.3196 - val_loss: 0.2134 - val_mean_absolute_error: 0.2134
# Epoch 38/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4367 - mean_absolute_error: 0.4367 - val_loss: 0.5486 - val_mean_absolute_error: 0.5486
# Epoch 39/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3503 - mean_absolute_error: 0.3503 - val_loss: 0.3084 - val_mean_absolute_error: 0.3084
# Epoch 40/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3234 - mean_absolute_error: 0.3234 - val_loss: 0.2226 - val_mean_absolute_error: 0.2226
# Epoch 41/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3253 - mean_absolute_error: 0.3253 - val_loss: 0.3968 - val_mean_absolute_error: 0.3968
# Epoch 42/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3995 - mean_absolute_error: 0.3995 - val_loss: 0.4465 - val_mean_absolute_error: 0.4465
# Epoch 43/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4292 - mean_absolute_error: 0.4292 - val_loss: 0.2055 - val_mean_absolute_error: 0.2055
# Epoch 44/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2509 - mean_absolute_error: 0.2509 - val_loss: 0.1860 - val_mean_absolute_error: 0.1860
# Epoch 45/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1986 - mean_absolute_error: 0.1986 - val_loss: 0.2135 - val_mean_absolute_error: 0.2135
# Epoch 46/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2592 - mean_absolute_error: 0.2592 - val_loss: 0.2622 - val_mean_absolute_error: 0.2622
# Epoch 47/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2565 - mean_absolute_error: 0.2565 - val_loss: 0.2122 - val_mean_absolute_error: 0.2122
# Epoch 48/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2811 - mean_absolute_error: 0.2811 - val_loss: 0.6359 - val_mean_absolute_error: 0.6359
# Epoch 49/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4402 - mean_absolute_error: 0.4402 - val_loss: 0.2589 - val_mean_absolute_error: 0.2589
# Epoch 50/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2993 - mean_absolute_error: 0.2993 - val_loss: 0.1633 - val_mean_absolute_error: 0.1633
# Epoch 51/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2098 - mean_absolute_error: 0.2098 - val_loss: 0.2190 - val_mean_absolute_error: 0.2190
# Epoch 52/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1911 - mean_absolute_error: 0.1911 - val_loss: 0.2171 - val_mean_absolute_error: 0.2171
# Epoch 53/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3141 - mean_absolute_error: 0.3141 - val_loss: 0.5844 - val_mean_absolute_error: 0.5844
# Epoch 54/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4978 - mean_absolute_error: 0.4978 - val_loss: 0.3340 - val_mean_absolute_error: 0.3340
# Epoch 55/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3362 - mean_absolute_error: 0.3362 - val_loss: 0.2660 - val_mean_absolute_error: 0.2660
# Epoch 56/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2490 - mean_absolute_error: 0.2490 - val_loss: 0.3887 - val_mean_absolute_error: 0.3887
# Epoch 57/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2945 - mean_absolute_error: 0.2945 - val_loss: 0.3248 - val_mean_absolute_error: 0.3248
# Epoch 58/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2386 - mean_absolute_error: 0.2386 - val_loss: 0.1772 - val_mean_absolute_error: 0.1772
# Epoch 59/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1799 - mean_absolute_error: 0.1799 - val_loss: 0.3826 - val_mean_absolute_error: 0.3826
# Epoch 60/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3036 - mean_absolute_error: 0.3036 - val_loss: 0.2810 - val_mean_absolute_error: 0.2810
# Epoch 61/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2817 - mean_absolute_error: 0.2817 - val_loss: 0.3309 - val_mean_absolute_error: 0.3309
# Epoch 62/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2066 - mean_absolute_error: 0.2066 - val_loss: 0.1711 - val_mean_absolute_error: 0.1711
# Epoch 63/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1782 - mean_absolute_error: 0.1782 - val_loss: 0.2297 - val_mean_absolute_error: 0.2297
# Epoch 64/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2973 - mean_absolute_error: 0.2973 - val_loss: 0.3012 - val_mean_absolute_error: 0.3012
# Epoch 65/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2394 - mean_absolute_error: 0.2394 - val_loss: 0.2094 - val_mean_absolute_error: 0.2094
# Epoch 66/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2803 - mean_absolute_error: 0.2803 - val_loss: 0.2019 - val_mean_absolute_error: 0.2019
# Epoch 67/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.3349 - mean_absolute_error: 0.3349 - val_loss: 0.1863 - val_mean_absolute_error: 0.1863
# Epoch 68/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2054 - mean_absolute_error: 0.2054 - val_loss: 0.2392 - val_mean_absolute_error: 0.2392
# Epoch 69/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2454 - mean_absolute_error: 0.2454 - val_loss: 0.2053 - val_mean_absolute_error: 0.2053
# Epoch 70/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2667 - mean_absolute_error: 0.2667 - val_loss: 0.3397 - val_mean_absolute_error: 0.3397
# Epoch 71/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2313 - mean_absolute_error: 0.2313 - val_loss: 0.1709 - val_mean_absolute_error: 0.1709
# Epoch 72/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1504 - mean_absolute_error: 0.1504 - val_loss: 0.4705 - val_mean_absolute_error: 0.4705
# Epoch 73/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2393 - mean_absolute_error: 0.2393 - val_loss: 0.2641 - val_mean_absolute_error: 0.2641
# Epoch 74/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2137 - mean_absolute_error: 0.2137 - val_loss: 0.1886 - val_mean_absolute_error: 0.1886
# Epoch 75/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2132 - mean_absolute_error: 0.2132 - val_loss: 0.3505 - val_mean_absolute_error: 0.3505
# Epoch 76/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2337 - mean_absolute_error: 0.2337 - val_loss: 0.6055 - val_mean_absolute_error: 0.6055
# Epoch 77/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2937 - mean_absolute_error: 0.2937 - val_loss: 0.2055 - val_mean_absolute_error: 0.2055
# Epoch 78/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1984 - mean_absolute_error: 0.1984 - val_loss: 0.1833 - val_mean_absolute_error: 0.1833
# Epoch 79/100
# 52/52 [==============================] - 0s 8ms/step - loss: 0.1851 - mean_absolute_error: 0.1851 - val_loss: 0.2181 - val_mean_absolute_error: 0.2181
# Epoch 80/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2249 - mean_absolute_error: 0.2249 - val_loss: 0.2000 - val_mean_absolute_error: 0.2000
# Epoch 81/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1985 - mean_absolute_error: 0.1985 - val_loss: 0.1992 - val_mean_absolute_error: 0.1992
# Epoch 82/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1812 - mean_absolute_error: 0.1812 - val_loss: 0.4968 - val_mean_absolute_error: 0.4968
# Epoch 83/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.4156 - mean_absolute_error: 0.4156 - val_loss: 0.2436 - val_mean_absolute_error: 0.2436
# Epoch 84/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2606 - mean_absolute_error: 0.2606 - val_loss: 0.2333 - val_mean_absolute_error: 0.2333
# Epoch 85/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2551 - mean_absolute_error: 0.2551 - val_loss: 0.4766 - val_mean_absolute_error: 0.4766
# Epoch 86/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.4401 - mean_absolute_error: 0.4401 - val_loss: 0.3246 - val_mean_absolute_error: 0.3246
# Epoch 87/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3697 - mean_absolute_error: 0.3697 - val_loss: 0.5654 - val_mean_absolute_error: 0.5654
# Epoch 88/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3430 - mean_absolute_error: 0.3430 - val_loss: 0.1718 - val_mean_absolute_error: 0.1718
# Epoch 89/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1816 - mean_absolute_error: 0.1816 - val_loss: 0.1802 - val_mean_absolute_error: 0.1802
# Epoch 90/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1605 - mean_absolute_error: 0.1605 - val_loss: 0.2930 - val_mean_absolute_error: 0.2930
# Epoch 91/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3582 - mean_absolute_error: 0.3582 - val_loss: 0.1657 - val_mean_absolute_error: 0.1657
# Epoch 92/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1640 - mean_absolute_error: 0.1640 - val_loss: 0.1569 - val_mean_absolute_error: 0.1569
# Epoch 93/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2057 - mean_absolute_error: 0.2057 - val_loss: 0.1692 - val_mean_absolute_error: 0.1692
# Epoch 94/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.1967 - mean_absolute_error: 0.1967 - val_loss: 0.1777 - val_mean_absolute_error: 0.1777
# Epoch 95/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2222 - mean_absolute_error: 0.2222 - val_loss: 0.1819 - val_mean_absolute_error: 0.1819
# Epoch 96/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2180 - mean_absolute_error: 0.2180 - val_loss: 0.2744 - val_mean_absolute_error: 0.2744
# Epoch 97/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.2342 - mean_absolute_error: 0.2342 - val_loss: 0.1542 - val_mean_absolute_error: 0.1542
# Epoch 98/100
# 52/52 [==============================] - 0s 4ms/step - loss: 0.1677 - mean_absolute_error: 0.1677 - val_loss: 0.4050 - val_mean_absolute_error: 0.4050
# Epoch 99/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.3462 - mean_absolute_error: 0.3462 - val_loss: 0.3848 - val_mean_absolute_error: 0.3848
# Epoch 100/100
# 52/52 [==============================] - 0s 5ms/step - loss: 0.2116 - mean_absolute_error: 0.2116 - val_loss: 0.1588 - val_mean_absolute_error: 0.1588

# %%
prediction=NN_model.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 0.14451107116025078
# MSE: 0.04901747788066379
# RMSE: 0.22139891120026717
